# %%
# 16
[14.2,98.15,34.2,34.3,0.12,0.17,16.46,12.31]
[14.28,100.12, 32.0,30.30,0.30,0.18,17.87,4.32]

# %%
𝑌=[33,22,444,121,353]

𝑍= [44,11,555,212, 535]

# %% [markdown]
# формула как в демо:
#
# числитель: знак суммы(y-z)^2
#
# знаменктель - 5

# %%
# 17
число цветов - [34,30,25,14,30]
рост куста - [1212,1876,1901,1543,1754]
вид кустарника - [1,2,3]

# %%
Исследователь Ксения занимается изучением студентов. Она собрала следующую выборку:

Количество часов (ч) : [8, 10, 11, 2, 6]

Закодированное наименование курса (1 – бакалавриат, 2 – магистратура, 3 – аспирантура): [1, 1, 1, 2, 2]

Оценка (балл): [6, 8, 10, 3, 5]

Выберите две характеристики, между которыми возможно корректно рассчитать интерпретируемый выборочный коэффициент корреляции Пирсона, и вычислите этот коэффициент по приведённым данным. Ответ округлите до сотых.

# %%
высота - [67.2, 76.3, 81.2, 45.5, 76.8]

вес - [545.2, 604.1, 550.8, 578.9, 569.4]

закодированное наименование дерева - [1,3,4]

# %%
# 18
число преступлений [254,1968,56,407]
уровень безработицы [0.15,0.43,0.11,0.27]

# %%
индивидуальная работа [531.0, 812.2,301.5,418.4]

опыт работы [5.4, 10.5,1.2,4.4]

# %% [markdown]
# 20
#
# Выведите среднее значение и стандартное отклонение переменной sqft_lot. В ответ выпишите сумму этих чисел, округленную до сотых.

# %% [markdown]
# Maternal Health Risk Data Set.csv
#
# Найдите размах переменной SystolicBP и среднее арифметическое HeartRate, в ответ напишите произведение этих значений, округленных до сотых.

# %% [markdown]
# 1. найти размах переменной calories и наименьшее значение calcium. в ответ вписать сумму этих двух показателей округленную до сотых.
#
# 2. найти среднеквадратичное отклонение переменной protein и среднее переменной calories. посчитать частное (отклонение на  среднее) и в ответ округленное число вписать

# %% [markdown]
# 21
#
# Определите самую популярную экспертную оценку состояния дома (переменная grade)

# %% [markdown]
# Maternal Health Risk Data Set.csv
#
# Определите значение, которое находится в середине переменной Age

# %% [markdown]
# 22
#
# Добавьте в таблицу новый признак Grade_Binned, который будет представлять собой кодированные значения состояния дома(переменная grade). Кодировку нужно проводить следующим образом: если эксперт поставил оценку 5 - 0, если больше и равно 5 , но меньше 8 - 1, если больше или равно 8, то 2
#
# Выведите среднее значение переменной price для домов, попавших в группу с кодировкой 2

# %% [markdown]
# Maternal Health Risk Data Set.csv
#
# Добавьте в таблицу новый признак risk, который будет представлять собой кодированные значения переменной BS. Кодировку проведите следующим образом: если значение BS строго больше стандартному отклонению этой переменной – 0, в противном случае – 1. Выведите медиану переменной risk.

# %% [markdown]
# 24
#
# Будем считать, что выбросами считаются значения, которые отличаются от среднего значения на 3 стандартных отклонения. Найдите количество выбросов для переменной sqft_basement.

# %% [markdown]
# Maternal Health Risk Data Set.csv
#
# Будем считать, что выбросами считаются наблюдения, которые отличаются от среднего значения переменной на 1 стандартное отклонение и более. Определите количество выбросов для переменной DiastolicBP.

# %% [markdown]
# 25
#
# Постройте сводную таблицу, по строкам которой расположена переменная grade, в столбца - sqft_lot и sqft_living, а в ячейках - среднее значение по этим переменным. Определите чему равно значение переменной grade, для которой разность по модулю между переменными sqft_lot и sqft_livin является наибольшей.

# %% [markdown]
# 26
#
# Найдите корреляции между переменными price, sqft_living, sqft_lot, bedrooms, bathrooms, floors. В ответ напишите название переменной, которая имеет наибольшую по модулю корреляцию с переменной price.

# %% [markdown]
# Maternal Health Risk Data Set.csv
#
# Найдите корреляции переменной Age с переменными SystolicBP, DiastolicBP, BS, BodyTemp, HeartRate. Выпишите наименьшую корреляцию по модулю
